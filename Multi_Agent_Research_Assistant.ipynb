# %%
# !pip install transformers torch

# %%
from transformers import pipeline

research_agent = pipeline(
    "text-generation",
    model="gpt2"
)

summary_agent = pipeline(
    "text-generation",
    model="gpt2"
)

analysis_agent = pipeline(
    "text-generation",
    model="gpt2"
)

print("Multi-Agent Research Assistant Ready")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Multi-Agent Research Assistant Ready

# %%
topic = input("Enter Research Topic: ")

# Research Agent
research_prompt = f"Give research information about {topic}"

research_output = research_agent(
    research_prompt,
    max_length=150,
    num_return_sequences=1
)

research_text = research_output[0]['generated_text']

print("\nResearch Agent Output:\n")
print(research_text)

# Summary Agent
summary_prompt = f"Summarize this:\n{research_text}"

summary_output = summary_agent(
    summary_prompt,
    max_length=100,
    num_return_sequences=1
)

summary_text = summary_output[0]['generated_text']

print("\nSummary Agent Output:\n")
print(summary_text)

# Analysis Agent
analysis_prompt = f"Analyze this research:\n{summary_text}"

analysis_output = analysis_agent(
    analysis_prompt,
    max_length=120,
    num_return_sequences=1
)

analysis_text = analysis_output[0]['generated_text']

print("\nAnalysis Agent Output:\n")
print(analysis_text)
# Out:
# Enter Research Topic: Artificial Intelligence
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=150) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=100) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Research Agent Output:
#
# Give research information about Artificial Intelligence and Artificial Language in the Open Source Project
#
# The Open Source Project (OSP) is a collaborative effort between the Open Source Foundation and the Software Freedom Conservancy (SFC), the Open Source Computer and Information Technology Foundation (OSIC), the Open Data Foundation (ODF) and the Open Society Foundations (OSF). OSP provides an open source, open source, collaborative and collaborative software project. This project is a collaborative effort between Open Source Foundation, SFC, OSIC, OSIC Open Source Project and the Open Source Software Foundation (OSF). OSIC is an open source project that enables a user's ability to freely use and publish freely-available and publicly available software without third-party legal or regulatory oversight. Open source software is used in a wide variety of applications and projects, including software development, research, and distribution. Open source software is used for many different purposes, including to build projects, and to create services. Open source software is provided under the Creative Commons Attribution 2.0 International license. These open source software are often distributed under the GPL license, which grants you the right to use and copy the software in any form, provided that you are not violating the terms and conditions of any of the licenses.
#
# OSP is
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=120) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Summary Agent Output:
#
# Summarize this:
# Give research information about Artificial Intelligence and Artificial Language in the Open Source Project
#
# The Open Source Project (OSP) is a collaborative effort between the Open Source Foundation and the Software Freedom Conservancy (SFC), the Open Source Computer and Information Technology Foundation (OSIC), the Open Data Foundation (ODF) and the Open Society Foundations (OSF). OSP provides an open source, open source, collaborative and collaborative software project. This project is a collaborative effort between Open Source Foundation, SFC, OSIC, OSIC Open Source Project and the Open Source Software Foundation (OSF). OSIC is an open source project that enables a user's ability to freely use and publish freely-available and publicly available software without third-party legal or regulatory oversight. Open source software is used in a wide variety of applications and projects, including software development, research, and distribution. Open source software is used for many different purposes, including to build projects, and to create services. Open source software is provided under the Creative Commons Attribution 2.0 International license. These open source software are often distributed under the GPL license, which grants you the right to use and copy the software in any form, provided that you are not violating the terms and conditions of any of the licenses.
#
# OSP is between the Open Source Foundation and the Open Society Foundations.
#
# To learn more about the SFC and OSIC, please visit their web site at http://www.ocsi.org/.
#
# For more information, please visit the SFC's website at http://www.ocsi.org/about/.
#
# References
#
# 1. Borsch, K. (2010). The Deep Web: a New and Radical Way of Thinking about Information Technology. Cambridge: MIT Press.
#
# 2. K. Borsch, J. (2009). The Web. New York: Oxford University Press.
#
# 3. C. K. Borsch, L. (2005). The Web. New York: Oxford University Press.
#
# 4. M. M. Kohn, A. (2005). The Web. New York: Oxford University Press.
#
# 5. J. L. Macdonald, N. (2005). The Web. New York: Oxford University Press.
#
# 6. T. Zaslavsky, G. (2003). "The Web's Edge: The Web's Future". New York: Oxford University Press.
#
# 7. K. Borsch, J. (2006). The Web
#
# Analysis Agent Output:
#
# Analyze this research:
# Summarize this:
# Give research information about Artificial Intelligence and Artificial Language in the Open Source Project
#
# The Open Source Project (OSP) is a collaborative effort between the Open Source Foundation and the Software Freedom Conservancy (SFC), the Open Source Computer and Information Technology Foundation (OSIC), the Open Data Foundation (ODF) and the Open Society Foundations (OSF). OSP provides an open source, open source, collaborative and collaborative software project. This project is a collaborative effort between Open Source Foundation, SFC, OSIC, OSIC Open Source Project and the Open Source Software Foundation (OSF). OSIC is an open source project that enables a user's ability to freely use and publish freely-available and publicly available software without third-party legal or regulatory oversight. Open source software is used in a wide variety of applications and projects, including software development, research, and distribution. Open source software is used for many different purposes, including to build projects, and to create services. Open source software is provided under the Creative Commons Attribution 2.0 International license. These open source software are often distributed under the GPL license, which grants you the right to use and copy the software in any form, provided that you are not violating the terms and conditions of any of the licenses.
#
# OSP is between the Open Source Foundation and the Open Society Foundations.
#
# To learn more about the SFC and OSIC, please visit their web site at http://www.ocsi.org/.
#
# For more information, please visit the SFC's website at http://www.ocsi.org/about/.
#
# References
#
# 1. Borsch, K. (2010). The Deep Web: a New and Radical Way of Thinking about Information Technology. Cambridge: MIT Press.
#
# 2. K. Borsch, J. (2009). The Web. New York: Oxford University Press.
#
# 3. C. K. Borsch, L. (2005). The Web. New York: Oxford University Press.
#
# 4. M. M. Kohn, A. (2005). The Web. New York: Oxford University Press.
#
# 5. J. L. Macdonald, N. (2005). The Web. New York: Oxford University Press.
#
# 6. T. Zaslavsky, G. (2003). "The Web's Edge: The Web's Future". New York: Oxford University Press.
#
# 7. K. Borsch, J. (2006). The Web Data Foundation, and the Open Society Foundations (OSF). OSIC is an open source project that aims to improve the open source community by advancing open source communication technology. SFC and OSIC work together to create Open Source Computer and Information Technology (OCIT) projects. This project is a collaborative effort among the Open Source Foundation and OSIC.
#
# OSIC is a project of the Open Source Foundation and OSIC. The Open Source Project (OSP) is a collaborative effort between the Open Source Foundation and OSIC. OSIC is an open source project that aims to improve the open source community by advancing open source communication technology. SFC and OSIC work together to create Open Source Computer and Information Technology (OCIT) projects. This project is a collaborative effort among the Open Source Foundation and OSIC. Open Source Projects are a subset of the Open Source Project (OSP) which is a collaboration between the Open Source Foundation and OSIC. Open Source Projects are open source projects that are open to the public.
#
# The Open Source Project was founded in 2012 by the Open Source Foundation (OSIC) and the Open University Association (OSU). OSIC is the organization behind the open source development of the Open Data project. More information about OSIC can
